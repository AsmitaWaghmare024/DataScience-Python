# %% [markdown]
# # Python

# %% [raw]
# ##What Is Programming?
#
# Imagine we have a very smart robot. But the robot is like a newborn baby
# it can work very fast, but it understands NOTHING by itself.
# So humans give instructions.
# Those instructions are called as PROGRAMS, A program is simply "A list of instructions for a computer."
#
#
# ##What Is Python?
#
# Python is a programming language. It is a language humans use to talk to computers.
# Like humans speak English, computers understand Python.
# Python is very popular in: AI, Data Science, Machine Learning, Automation

# %% [markdown]
# Computers only understand (INPUT, PROCESS, OUTPUT )
# For example:
# Like a juice machine.
#
# INPUT Mango + Sugar + Milk
#
# PROCESS Blend everything
#
# OUTPUT Mango shake
#
# Programming works exactly the same way.
# storing information,
# processing information,
# showing results.

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ##What Does print() Mean?
#
# Imagine computer has a mouth.
# print() means "Computer, say this on screen."
#
# Example:

# %%
print("I am learning Python") #Anything inside quotes " " is treated as TEXT.
# Out:
# I am learning Python

# %% [markdown]
# # VARIABLES

# %% [markdown]
# A variable is a box that stores information.
#
# For example:
# Imagine a lunch box.You can put food inside. Similarly, variables store data.

# %%
name = "James"
#This means: create a box called name and store "James" inside it
#name â†’ James

# %%
name = "James"
print(name)
# Computer looks inside the box and shows what is stored.
# Out:
# James

# %%
age = 22 #age â†’ 22

# %% [markdown]
# Addition

# %%
a = 5 #Create box a; Store 5
b = 3 #Create box b; store 3

print(a + b) #Take values from boxes; Add them; Show answer
# Out:
# 8
