# %% [markdown]
# # DICTIONARIES & SETS

# %% [markdown]
# real-world data often looks like this

# %%
{
    "name": "James",
    "age": 24,
    "city": "London"
}
# Out:
# {'name': 'James', 'age': 24, 'city': 'London'}

# %% [markdown]
# This is a Dictionary.

# %% [markdown]
# 1. APIs
# 2. JSON data
# 3. Machine Learning datasets
# 4. Database records
#
# all using similar structures.

# %% [markdown]
# # DICTIONARIES
# Think of a Dictionary as
#
# Key -> Value

# %% [markdown]
# Creating a Dictionary

# %%
student = {
    "name": "James",
    "age": 24,
    "city": "London"
}

print(student)
# Out:
# {'name': 'James', 'age': 24, 'city': 'London'}

# %% [markdown]
# student
# │
# ├── name -> James
# ├── age -> 24
# └── city -> London

# %% [markdown]
# Accessing Values

# %%
student = {
    "name": "James",
    "age": 24
}

print(student["name"])
# Out:
# James

# %% [markdown]
# Why Use Keys?
#
# Instead of

# %% [raw]
# student[0]
# student[1]

# %% [markdown]
# We use meaningful names

# %% [markdown]
# student["name]
# student["age"]

# %% [markdown]
# Much easier.

# %% [markdown]
# Updating Data

# %%
student["age"] = 25

print(student)
# Out:
# {'name': 'James', 'age': 25}

# %% [markdown]
# Adding New Data

# %%
student["course"] = "Data Science"

# %% [markdown]
# Now:
#
# name
# age
# course
#
# all exist.

# %% [markdown]
# Loop Through Dictionary

# %%
student = {
    "name": "James",
    "age": 24,
    "city": "London"
}

for key, value in student.items():
    print(key, ":", value)
# Out:
# name : James
# age : 24
# city : London

# %%
employee = {
    "name": "John",
    "salary": 50000,
    "department": "IT"
}

# %% [markdown]
# This looks very similar to records stored in databases.

# %% [markdown]
# Student Profile System

# %%
student = {}

student["name"] = input("Enter Name: ")
student["age"] = int(input("Enter Age: "))
student["city"] = input("Enter City: ")

print("\nStudent Profile")

for key, value in student.items():
    print(key, ":", value)
# Out:
# Enter Name: Lily
# Enter Age: 26
# Enter City: Liverpool
#
# Student Profile
# name : Lily
# age : 26
# city : Liverpool

# %% [markdown]
# # SETS

# %% [markdown]
# A Set is Collection of unique values No duplicates allowed.

# %%
numbers = {1, 2, 3, 4, 4, 4, 2}

print(numbers)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# Duplicates automatically removed.

# %% [markdown]
# Why Are Sets Useful?
#
# Imagine

# %%
students = [
    "James",
    "Rahul",
    "John",
    "Rahul",
    "John"
]

# %% [markdown]
# Need unique names.

# %%
unique_students = set(students)

print(unique_students)
# Out:
# {'James', 'Rahul', 'John'}

# %% [markdown]
# Add Items

# %%
fruits = {"apple", "banana"}

fruits.add("mango")

print(fruits)
# Out:
# {'apple', 'mango', 'banana'}

# %% [markdown]
# Remove Items

# %%
fruits.remove("banana")

# %% [markdown]
# Check Membership

# %%
fruits = {"apple", "banana", "mango"}

print("Guava" in fruits)
# Out:
# False

# %%
cities = [
    "Mumbai",
    "Pune",
    "Mumbai",
    "Delhi",
    "Pune"
]

# %%
unique_cities = set(cities)

print(unique_cities)
# Out:
# {'Delhi', 'Pune', 'Mumbai'}

# %% [markdown]
# This is a very common data-cleaning task.

# %% [markdown]
# Unique Words Finder

# %%
sentence = input("Enter a sentence: ")

words = sentence.lower().split()

unique_words = set(words)

print("Unique words:")

for word in unique_words:
    print(word)
# Out:
# Enter a sentence: What we think we become
# Unique words:
# become
# what
# we
# think

# %% [markdown]
# Difference
#
# | Feature            | List       | Set           | Dictionary     |
# | ------------------ | ---------- | ------------- | -------------- |
# | Ordered            | ✅          | ❌             | ✅              |
# | Duplicates Allowed | ✅          | ❌             | Keys ❌         |
# | Indexing           | ✅          | ❌             | By Key         |
# | Use Case           | Store data | Unique values | Key-Value data |

# %% [markdown]
# Contact book dictionary

# %%
contacts = {
    "Mom": "9876543210",
    "Dad": "9876543211",
    "Friend": "9876543212"
}

# Ask user for a name
name = input("Enter a contact name: ")

# Check if name exists in dictionary
if name in contacts:
    print(name, ":", contacts[name])
else:
    print("Sorry,", name, "not found in contacts.")
